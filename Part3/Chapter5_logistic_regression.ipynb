# %% [markdown]
# <a href="https://colab.research.google.com/github/Goseungeun/2026_BigData_Analyst/blob/main/Part3/Chapter5_logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##로지스틱 회귀 분석

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bae-v3/main/part3/ch5/health_survey2.csv")
print(df.head())
# Out:
#    age   bmi  smoker  activity_level  disease lifestyle
# 0   62  35.2       0               0        1         S
# 1   65  18.6       0               2        1         A
# 2   71  33.2       0               1        1         M
# 3   18  37.1       1               2        0         A
# 4   21  17.6       0               0        0         S

# %%
from statsmodels.formula.api import logit
model = logit('disease ~ age+bmi+smoker+lifestyle',data=df).fit()
print(model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.641392
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                disease   No. Observations:                 1000
# Model:                          Logit   Df Residuals:                      994
# Method:                           MLE   Df Model:                            5
# Date:                Sun, 14 Jun 2026   Pseudo R-squ.:                 0.05341
# Time:                        12:09:06   Log-Likelihood:                -641.39
# converged:                       True   LL-Null:                       -677.58
# Covariance Type:            nonrobust   LLR p-value:                 3.284e-14
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         -1.9881      0.306     -6.492      0.000      -2.588      -1.388
# lifestyle[T.M]     0.0250      0.167      0.150      0.881      -0.302       0.352
# lifestyle[T.S]     0.0797      0.168      0.474      0.636      -0.250       0.409
# age                0.0175      0.004      4.618      0.000       0.010       0.025
# bmi                0.0563      0.009      6.401      0.000       0.039       0.074
# smoker             0.3125      0.149      2.103      0.035       0.021       0.604
# ==================================================================================

# %% [markdown]
# ## 오즈와 오즈비

# %%
import numpy as np
print(model.params['bmi'])
print(np.exp(model.params['bmi']))
# Out:
# 0.0563227540288301
# 1.057939082740907

# %%
print(np.exp(model.params['bmi']*3))
# Out:
# 1.184082558017788

# %% [markdown]
# ## 범주형 변수의 오즈비

# %%
print(np.exp(model.params['lifestyle[T.S]']))
# Out:
# 1.0829249581859632

# %% [markdown]
# ## 로지스틱 회귀 모델의 예측

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bae-v3/main/part3/ch5/health_survey2.csv")

train = df.iloc[:700]
test = df.iloc[700:]
print(train.shape, test.shape)
# Out:
# (700, 6) (300, 6)

# %%
# 방법 1
from statsmodels.formula.api import logit
model = logit('disease ~ age + bmi + smoker + lifestyle', data = train).fit()
pred = model.predict(test)
print(pred.sort_values())
print(test.loc[840,'bmi'])
# Out:
# Optimization terminated successfully.
#          Current function value: 0.637966
#          Iterations 5
# 773    0.240990
# 996    0.252992
# 863    0.287612
# 777    0.313125
# 861    0.323196
#          ...
# 852    0.874378
# 889    0.877035
# 946    0.878470
# 985    0.896081
# 840    0.900602
# Length: 300, dtype: float64
# 42.2

# %%
#방법 2
from statsmodels.formula.api import logit
model = logit('disease ~ age + bmi + smoker + lifestyle',data=train).fit()
pred = model.predict(test)
max_idx = pred.idxmax()
test.loc[max_idx]
# Out:
# Optimization terminated successfully.
#          Current function value: 0.637966
#          Iterations 5
# age                 72
# bmi               42.2
# smoker               1
# activity_level       0
# disease              0
# lifestyle            S
# Name: 840, dtype: object

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                disease   No. Observations:                  700
# Model:                          Logit   Df Residuals:                      694
# Method:                           MLE   Df Model:                            5
# Date:                Sun, 14 Jun 2026   Pseudo R-squ.:                 0.05746
# Time:                        12:25:55   Log-Likelihood:                -446.58
# converged:                       True   LL-Null:                       -473.80
# Covariance Type:            nonrobust   LLR p-value:                 1.694e-10
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         -2.0554      0.368     -5.579      0.000      -2.778      -1.333
# lifestyle[T.M]     0.0368      0.198      0.186      0.852      -0.351       0.425
# lifestyle[T.S]     0.3639      0.201      1.808      0.071      -0.031       0.758
# age                0.0185      0.005      4.083      0.000       0.010       0.027
# bmi                0.0544      0.010      5.182      0.000       0.034       0.075
# smoker             0.2650      0.178      1.485      0.138      -0.085       0.615
# ==================================================================================
# """

# %%
from statsmodels.formula.api import logit

model = logit('disease ~ age + bmi',data = train).fit()
pred = model.predict(test)
pred = (pred>0.4).astype(int)

from sklearn.metrics import recall_score
print(recall_score(test['disease'],pred))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.642623
#          Iterations 5
# 0.96
