# %% [markdown]
# <a href="https://colab.research.google.com/github/Goseungeun/2026_BigData_Analyst/blob/main/Part1/chapter1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Python 확인 문제

listbox = ["감사","행복","사랑","성공","긍정","변화","성장","희망"]

#Q1
print(len(listbox))

#Q2
print(listbox[0])

#Q3
print(listbox[-1])

#Q4
print(listbox[:3])

#Q5
print(listbox[-2])

#Q6
print(listbox[1:3])

#Q7
listbox[5] = "웃음"
listbox
# Out:
# 8
# 감사
# 희망
# ['감사', '행복', '사랑']
# 성장
# ['행복', '사랑']
# ['감사', '행복', '사랑', '성공', '긍정', '웃음', '성장', '희망']

# %%
cols = ['name','age','phone']

#Q8
for col in cols:
  print(col)
# Out:
# name
# age
# phone

# %%
listbox = [15,46,78,24,56]

#Q9
def sub(data):
  max_data = max(data)
  min_data = min(data)

  return max_data - min_data

print(sub(listbox))
# Out:
# 63

# %%
str_data = "여러분의 합격을 응원합니다!"

#Q10
def rep(text):
  return text.replace("여러분","당신")

rep(str_data)
# Out:
# '당신의 합격을 응원합니다!'
